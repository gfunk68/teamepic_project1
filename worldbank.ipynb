# %%
import pandas as pd
import requests
from pprint import pprint
import os

# variables
url = "http://api.worldbank.org/v2/"

# %%
# Compile the query URL
query_url = f"{url}countries?format=json"
print(query_url)
# Out:
# http://api.worldbank.org/v2/countries?format=json

# %%
get_pages = requests.get(query_url).json()[0]['pages']

# %%
all_pages_list = []
country_list = []
poverty_list = []
region = []
capital_city = []
lat_long = []
iso2code = []

for page in range(get_pages):
    all_pages_list.append(requests.get(f'{query_url}&page={page+1}').json()[1])
# pprint(all_pages_list)
for y in range(len(all_pages_list)):
    for x in range(len(all_pages_list[y])):
        country_list.append(all_pages_list[y][x]['name'])
        poverty_list.append(all_pages_list[y][x]['incomeLevel']['value'])
        region.append(all_pages_list[y][x]['region']['value'])
        capital_city.append(all_pages_list[y][x]['capitalCity'])
        lat_long.append(f"{all_pages_list[y][x]['latitude']} , {all_pages_list[y][x]['longitude']}")
        iso2code.append(all_pages_list[y][x]['iso2Code'])
# country_list
# poverty_list
# region
# capital_city
# lat_long

# %%
#create dataframe from all derived worldbank info
worldbank_df = pd.DataFrame({"Country": country_list,"Country Code": iso2code,"Region": region, "Poverty Level":poverty_list,"Capital City":capital_city,"Lat/Long":lat_long})

#drop rows that are not countries
worldbank_df = worldbank_df[worldbank_df.Region != "Aggregates"]
worldbank_df = worldbank_df.reset_index(drop=True)

worldbank_df
# Out:
#                             Country Country Code                      Region  \
# 0                             Aruba           AW  Latin America & Caribbean
# 1                       Afghanistan           AF                  South Asia
# 2                            Angola           AO         Sub-Saharan Africa
# 3                           Albania           AL       Europe & Central Asia
# 4                           Andorra           AD       Europe & Central Asia
# 5              United Arab Emirates           AE  Middle East & North Africa
# 6                         Argentina           AR  Latin America & Caribbean
# 7                           Armenia           AM       Europe & Central Asia
# 8                    American Samoa           AS         East Asia & Pacific
# 9               Antigua and Barbuda           AG  Latin America & Caribbean
# 10                        Australia           AU         East Asia & Pacific
# 11                          Austria           AT       Europe & Central Asia
# 12                       Azerbaijan           AZ       Europe & Central Asia
# 13                          Burundi           BI         Sub-Saharan Africa
# 14                          Belgium           BE       Europe & Central Asia
# 15                            Benin           BJ         Sub-Saharan Africa
# 16                     Burkina Faso           BF         Sub-Saharan Africa
# 17                       Bangladesh           BD                  South Asia
# 18                         Bulgaria           BG       Europe & Central Asia
# 19                          Bahrain           BH  Middle East & North Africa
# 20                     Bahamas, The           BS  Latin America & Caribbean
# 21           Bosnia and Herzegovina           BA       Europe & Central Asia
# 22                          Belarus           BY       Europe & Central Asia
# 23                           Belize           BZ  Latin America & Caribbean
# 24                          Bermuda           BM               North America
# 15            Low income           Porto-Novo          6.4779 , 2.6323
# 16            Low income          Ouagadougou       12.3605 , -1.53395
# 17   Lower middle income                Dhaka        23.7055 , 90.4113
# 18   Upper middle income                Sofia        42.7105 , 23.3238
# 19           High income               Manama        26.1921 , 50.5354
# 20           High income               Nassau        25.0661 , -77.339
# 21   Upper middle income             Sarajevo        43.8607 , 18.4214
# 22   Upper middle income                Minsk        53.9678 , 27.5766
# 23   Upper middle income             Belmopan       17.2534 , -88.7713
# 24           High income             Hamilton        32.3293 , -64.706
# 25   Lower middle income               La Paz      -13.9908 , -66.1936
# 26   Upper middle income             Brasilia      -15.7801 , -47.9292
# 27           High income           Bridgetown       13.0935 , -59.6105
# 28           High income  Bandar Seri Begawan        4.94199 , 114.946
# 29   Lower middle income              Thimphu        27.5768 , 89.6177
# ..                   ...                  ...                      ...
# 188           Low income            N'Djamena        12.1048 , 15.0445
# 189           Low income                 Lome          6.1228 , 1.2255
# 190  Upper middle income              Bangkok        13.7308 , 100.521
# 191           Low income             Dushanbe        38.5878 , 68.7864
# 192  Upper middle income             Ashgabat        37.9509 , 58.3794
# 193  Lower middle income                 Dili       -8.56667 , 125.567
# 194  Upper middle income           Nuku'alofa       -21.136 , -175.216
# 195          High income        Port-of-Spain       10.6596 , -61.4789
# 196  Lower middle income                Tunis          36.7899 , 10.21
# 197  Upper middle income               Ankara        39.7153 , 32.3606
# 198  Upper middle income             Funafuti  -8.6314877 , 179.089567
# 199          High income                                            ,
# 200           Low income               Dodoma       -6.17486 , 35.7382
# 201           Low income              Kampala       0.314269 , 32.5729
# 202  Lower middle income                 Kiev        50.4536 , 30.5038
# 203          High income           Montevideo      -34.8941 , -56.0675
# 204          High income      Washington D.C.        38.8895 , -77.032
# 205  Lower middle income             Tashkent         41.3052 , 69.269
# 206  Upper middle income            Kingstown       13.2035 , -61.2653
# 207  Upper middle income              Caracas       9.08165 , -69.8371
# 208          High income            Road Town   18.431389 , -64.623056
# 209          High income     Charlotte Amalie       18.3358 , -64.8963
# 210  Lower middle income                Hanoi        21.0069 , 105.825
# 211  Lower middle income            Port-Vila       -17.7404 , 168.321
# 212  Upper middle income                 Apia      -13.8314 , -171.752
# 213  Upper middle income             Pristina          42.565 , 20.926
# 214           Low income               Sana'a         15.352 , 44.2075
# 215  Upper middle income             Pretoria        -25.746 , 28.1871
# 216  Lower middle income               Lusaka       -15.3982 , 28.2937
# 217  Lower middle income               Harare       -17.8312 , 31.0672
#
# [218 rows x 6 columns]

# %%
worldbank_df.to_csv(os.path.join("Resources","worldbank.csv"), index=None)
